# %%
import numpy as np

# %%
import pandas as pd

# %%
import seaborn as sna

# %%
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('dataset.csv')

# %%
data.head()
# Out:
#    Unnamed: 0 SUBDIVISION  YEAR   JAN   FEB   MAR    APR    MAY     JUN
# 0           1      KERALA  1901  28.7  44.7  51.6  160.0  174.7   824.6  \
# 1           2      KERALA  1902   6.7   2.6  57.3   83.9  134.5   390.9
# 2           3      KERALA  1903   3.2  18.6   3.1   83.6  249.7   558.6
# 3           4      KERALA  1904  23.7   3.0  32.2   71.5  235.7  1098.2
# 4           5      KERALA  1905   1.2  22.3   9.4  105.9  263.3   850.2
#
#       JUL  ...    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  Jun-Sep  Oct-Dec
# 0   743.0  ...  350.8   48.4  3248.6     73.4    386.2   2122.8    666.1  \
# 1  1205.0  ...  158.3  121.5  3326.6      9.3    275.7   2403.4    638.2
# 2  1022.5  ...  157.0   59.0  3271.2     21.7    336.3   2343.0    570.1
# 3   725.5  ...   33.9    3.3  3129.7     26.7    339.4   2398.2    365.3
# 4   520.5  ...   74.4    0.2  2741.6     23.4    378.5   1881.5    458.1
#
#    flood  10days_june  increased Rainfall
# 0      0   274.866667               649.9
# ...

# %%
data.tail()
# Out:
#      Unnamed: 0               SUBDIVISION  YEAR  JAN   FEB   MAR   APR    MAY
# 800         801  SOUTH INTERIOR KARNATAKA  2011  2.1  12.4  12.4  80.2   83.5  \
# 801         802  SOUTH INTERIOR KARNATAKA  2012  4.6   5.5   8.1  99.0   45.6
# 802         803  SOUTH INTERIOR KARNATAKA  2013  0.5  10.1  11.7  34.6   95.6
# 803         804  SOUTH INTERIOR KARNATAKA  2014  0.4   2.4  17.7  46.7  130.5
# 804         805  SOUTH INTERIOR KARNATAKA  2015  1.7   0.2  24.4  80.5  125.3
#
#        JUN    JUL  ...    NOV   DEC  ANNUAL  Jan-Feb  Mar-May  Jun-Sep
# 800  177.1  202.4  ...   56.7   5.0  1087.4     14.5    176.1    690.2  \
# 801   81.8  144.7  ...   82.6   6.2   877.8     10.1    152.6    563.5
# 802  176.2  307.4  ...   24.9   2.4  1110.7     10.6    142.0    827.1
# 803  106.8  271.6  ...   20.2  18.7  1184.2      2.8    195.0    794.5
# 804  218.7  112.0  ...  138.1   4.4  1112.5      1.9    230.2    631.8
#
#      Oct-Dec  flood  10days_june  increased Rainfall
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0            0
# SUBDIVISION           0
# YEAR                  0
# JAN                   1
# FEB                   0
# MAR                   0
# APR                   0
# MAY                   0
# JUN                   0
# JUL                   0
# AUG                   0
# SEP                   0
# OCT                   0
# NOV                   0
# DEC                   0
# ANNUAL                1
# Jan-Feb               1
# Mar-May               0
# Jun-Sep               0
# Oct-Dec               0
# flood                 0
# 10days_june           0
# increased Rainfall    0
# dtype: int64

# %%
print(data.shape)
# Out:
# (805, 23)

# %%
data.describe()
# Out:
#        Unnamed: 0         YEAR         JAN        FEB         MAR         APR
# count  805.000000   805.000000  804.000000  805.00000  805.000000  805.000000  \
# mean   403.000000  1958.000000    8.455473    8.62646   15.013292   42.570559
# std    232.527776    33.217023   17.033706   14.95067   22.222653   39.125447
# min      1.000000  1901.000000    0.000000    0.00000    0.000000    0.000000
# 25%    202.000000  1929.000000    0.100000    0.10000    1.700000   15.700000
# 50%    403.000000  1958.000000    1.900000    2.40000    6.400000   30.800000
# 75%    604.000000  1987.000000    8.750000   10.50000   20.000000   55.600000
# max    805.000000  2015.000000  141.200000  131.30000  217.200000  238.000000
#
#               MAY          JUN          JUL          AUG  ...         NOV
# count  805.000000   805.000000   805.000000   805.000000  ...  805.000000  \
# mean    92.807081   293.702236   384.358634   273.737764  ...   83.694907
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of      Unnamed: 0               SUBDIVISION  YEAR   JAN   FEB   MAR    APR
# 0             1                    KERALA  1901  28.7  44.7  51.6  160.0  \
# 1             2                    KERALA  1902   6.7   2.6  57.3   83.9
# 2             3                    KERALA  1903   3.2  18.6   3.1   83.6
# 3             4                    KERALA  1904  23.7   3.0  32.2   71.5
# 4             5                    KERALA  1905   1.2  22.3   9.4  105.9
# ..          ...                       ...   ...   ...   ...   ...    ...
# 800         801  SOUTH INTERIOR KARNATAKA  2011   2.1  12.4  12.4   80.2
# 801         802  SOUTH INTERIOR KARNATAKA  2012   4.6   5.5   8.1   99.0
# 802         803  SOUTH INTERIOR KARNATAKA  2013   0.5  10.1  11.7   34.6
# 803         804  SOUTH INTERIOR KARNATAKA  2014   0.4   2.4  17.7   46.7
# 804         805  SOUTH INTERIOR KARNATAKA  2015   1.7   0.2  24.4   80.5
#
# ...

# %%
import seaborn as sns

# %%
plt.figure(figsize = (15,8))

# %%
sns.heatmap(data.iloc[:,2:14].cov())
# Out:
# <Axes: >

# %%
plt.figure(figsize = (15,8))

# %%
sna.heatmap(data.iloc[:,2:14].corr())
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
type(data.flood)
data['flood'] = le.fit_transform(data.flood)
data.head()
# Out:
#    Unnamed: 0 SUBDIVISION  YEAR   JAN   FEB   MAR    APR    MAY     JUN
# 0           1      KERALA  1901  28.7  44.7  51.6  160.0  174.7   824.6  \
# 1           2      KERALA  1902   6.7   2.6  57.3   83.9  134.5   390.9
# 2           3      KERALA  1903   3.2  18.6   3.1   83.6  249.7   558.6
# 3           4      KERALA  1904  23.7   3.0  32.2   71.5  235.7  1098.2
# 4           5      KERALA  1905   1.2  22.3   9.4  105.9  263.3   850.2
#
#       JUL  ...    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  Jun-Sep  Oct-Dec
# 0   743.0  ...  350.8   48.4  3248.6     73.4    386.2   2122.8    666.1  \
# 1  1205.0  ...  158.3  121.5  3326.6      9.3    275.7   2403.4    638.2
# 2  1022.5  ...  157.0   59.0  3271.2     21.7    336.3   2343.0    570.1
# 3   725.5  ...   33.9    3.3  3129.7     26.7    339.4   2398.2    365.3
# 4   520.5  ...   74.4    0.2  2741.6     23.4    378.5   1881.5    458.1
#
#    flood  10days_june  increased Rainfall
# 0      0   274.866667               649.9
# ...

# %%
data.iloc[0][2:14].sum()
# Out:
# 5101.199999999999

# %%
data_input = data.iloc[:,2:14].values

# %%
print(data_input)
# Out:
# [[1.901e+03 2.870e+01 4.470e+01 ... 1.977e+02 2.669e+02 3.508e+02]
#  [1.902e+03 6.700e+00 2.600e+00 ... 4.916e+02 3.584e+02 1.583e+02]
#  [1.903e+03 3.200e+00 1.860e+01 ... 3.418e+02 3.541e+02 1.570e+02]
#  ...
#  [2.013e+03 5.000e-01 1.010e+01 ... 1.918e+02 1.037e+02 2.490e+01]
#  [2.014e+03 4.000e-01 2.400e+00 ... 1.616e+02 1.529e+02 2.020e+01]
#  [2.015e+03 1.700e+00 2.000e-01 ... 1.645e+02 1.061e+02 1.381e+02]]

# %%
data_output = data.iloc[:,-1].values

# %%
print(data_output)
# Out:
# [6.4990e+02 2.5640e+02 3.0890e+02 8.6250e+02 5.8690e+02 2.5410e+02
#  6.6950e+02 4.5000e+02 2.3150e+02 5.3120e+02 8.0940e+02 7.3090e+02
#  3.4290e+02 4.0110e+02 5.4160e+02 7.2120e+02 5.8080e+02 2.1870e+02
#  3.8980e+02 8.7660e+02 3.8500e+02 3.6950e+02 6.4250e+02 8.2630e+02
#  4.3060e+02 3.4130e+02 4.5480e+02 5.0880e+02 7.9860e+02 2.2820e+02
#  4.1000e+02 3.0550e+02 1.2050e+02 7.4620e+02 3.7470e+02 1.5430e+02
#  3.4850e+02 5.0200e+02 5.2070e+02 3.8900e+02 3.8010e+02 6.2170e+02
#  3.1610e+02 2.8620e+02 4.9640e+02 8.3600e+02 4.7040e+02 6.9790e+02
#  9.6300e+01 3.9630e+02 6.2560e+02 3.6210e+02 2.8510e+02 6.1880e+02
#  2.3820e+02 4.0410e+02 4.9080e+02 3.5980e+02 5.2560e+02 5.9700e+01
#  5.0470e+02 2.2750e+02 2.3620e+02 2.8460e+02 3.8320e+02 4.0100e+02
#  2.9680e+02 6.0640e+02 3.2310e+02 2.4620e+02 5.7210e+02 3.4200e+01
#  4.9710e+02 4.5400e+01 7.0220e+02 1.2100e+02 2.9320e+02 3.6130e+02
#  4.5520e+02 6.4060e+02 7.4610e+02 4.6400e+02 2.4680e+02 7.5800e+02
# ...

# %%
data['flood'].value_counts()
# Out:
# flood
# 0    683
# 1    122
# Name: count, dtype: int64

# %%
copy_df_data = data.copy()

# %%
copy_df_data.columns[3:15]
# Out:
# Index(['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT',
#        'NOV', 'DEC'],
#       dtype='object')

# %%
sns.set(style = 'whitegrid', color_codes = True)

# %%
copy_df_data = data.copy()

# %%
copy_df_data.head()
# Out:
#    Unnamed: 0 SUBDIVISION  YEAR   JAN   FEB   MAR    APR    MAY     JUN
# 0           1      KERALA  1901  28.7  44.7  51.6  160.0  174.7   824.6  \
# 1           2      KERALA  1902   6.7   2.6  57.3   83.9  134.5   390.9
# 2           3      KERALA  1903   3.2  18.6   3.1   83.6  249.7   558.6
# 3           4      KERALA  1904  23.7   3.0  32.2   71.5  235.7  1098.2
# 4           5      KERALA  1905   1.2  22.3   9.4  105.9  263.3   850.2
#
#       JUL  ...    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  Jun-Sep  Oct-Dec
# 0   743.0  ...  350.8   48.4  3248.6     73.4    386.2   2122.8    666.1  \
# 1  1205.0  ...  158.3  121.5  3326.6      9.3    275.7   2403.4    638.2
# 2  1022.5  ...  157.0   59.0  3271.2     21.7    336.3   2343.0    570.1
# 3   725.5  ...   33.9    3.3  3129.7     26.7    339.4   2398.2    365.3
# 4   520.5  ...   74.4    0.2  2741.6     23.4    378.5   1881.5    458.1
#
#    flood  10days_june  increased Rainfall
# 0      0   274.866667               649.9
# ...
